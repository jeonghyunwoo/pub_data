# %% [markdown]
# ### **가계부채+연체 기사검색**

# %%
from konlpy.tag import Okt
okt = Okt()
# 이게 잘 안되면 전용이지넷을 재부팅한다

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %%
from navsch import *

# %%
b_rng = pd.date_range('2002-01-01','2019-04-01',freq='MS').strftime('%Y.%m.%d').tolist()[:-1]
e_rng = pd.date_range('2002-01-01','2019-04-01',freq='M').strftime('%Y.%m.%d').tolist()

# %%
# %%time
dfs = []
for beg, end in zip(b_rng,e_rng):
    s = time.time()
    dfs.append(naver_search_d('가계부채+연체',beg,end,pages=1))
    e = time.time() - s
    print('{}~{} done, {} elapsed'.format(beg,end,time.strftime('%H:%M:%S',time.gmtime(e))))
newsdf = pd.concat(dfs,axis=0)    
# Wall time: 1h 12min 22s
newsdf.to_pickle('data/newsdf_가계부채_연체_03_19.pkl')
# Out:
# 2002.01.01~2002.01.31 done, 00:00:11 elapsed
# 2002.02.01~2002.02.28 done, 00:00:17 elapsed
# 2002.03.01~2002.03.31 done, 00:00:16 elapsed
# 2002.04.01~2002.04.30 done, 00:00:20 elapsed
# 2002.05.01~2002.05.31 done, 00:00:17 elapsed
# 2002.06.01~2002.06.30 done, 00:00:04 elapsed
# 2002.07.01~2002.07.31 done, 00:00:02 elapsed
# 2002.08.01~2002.08.31 done, 00:00:04 elapsed
# 2002.09.01~2002.09.30 done, 00:00:20 elapsed
# 2002.10.01~2002.10.31 done, 00:00:18 elapsed
# 2002.11.01~2002.11.30 done, 00:00:19 elapsed
# 2002.12.01~2002.12.31 done, 00:00:21 elapsed
# 2003.01.01~2003.01.31 done, 00:00:17 elapsed
# 2003.02.01~2003.02.28 done, 00:00:08 elapsed
# 2003.03.01~2003.03.31 done, 00:00:20 elapsed
# 2003.04.01~2003.04.30 done, 00:00:17 elapsed
# 2003.05.01~2003.05.31 done, 00:00:13 elapsed
# 2003.06.01~2003.06.30 done, 00:00:20 elapsed
# 2003.07.01~2003.07.31 done, 00:00:05 elapsed
# 2003.08.01~2003.08.31 done, 00:00:17 elapsed
# 2003.09.01~2003.09.30 done, 00:00:18 elapsed
# 2003.10.01~2003.10.31 done, 00:00:14 elapsed
# 2003.11.01~2003.11.30 done, 00:00:17 elapsed
# 2003.12.01~2003.12.31 done, 00:00:17 elapsed
# 2004.01.01~2004.01.31 done, 00:00:20 elapsed
# 2004.02.01~2004.02.29 done, 00:00:18 elapsed
# 2004.03.01~2004.03.31 done, 00:00:19 elapsed
# 2004.04.01~2004.04.30 done, 00:00:18 elapsed
# 2004.05.01~2004.05.31 done, 00:00:20 elapsed
# 2004.06.01~2004.06.30 done, 00:00:20 elapsed
# 2004.07.01~2004.07.31 done, 00:00:20 elapsed
# 2004.08.01~2004.08.31 done, 00:00:19 elapsed
# 2004.09.01~2004.09.30 done, 00:00:21 elapsed
# 2004.10.01~2004.10.31 done, 00:00:23 elapsed
# 2004.11.01~2004.11.30 done, 00:00:21 elapsed
# 2004.12.01~2004.12.31 done, 00:00:16 elapsed
# 2005.01.01~2005.01.31 done, 00:00:17 elapsed
# 2005.02.01~2005.02.28 done, 00:00:19 elapsed
# 2005.03.01~2005.03.31 done, 00:00:13 elapsed
# 2005.04.01~2005.04.30 done, 00:00:21 elapsed
# 2005.05.01~2005.05.31 done, 00:00:18 elapsed
# 2005.06.01~2005.06.30 done, 00:00:18 elapsed
# 2005.07.01~2005.07.31 done, 00:00:21 elapsed
# 2005.08.01~2005.08.31 done, 00:00:10 elapsed
# 2005.09.01~2005.09.30 done, 00:00:10 elapsed
# 2005.10.01~2005.10.31 done, 00:00:00 elapsed
# 2005.11.01~2005.11.30 done, 00:00:09 elapsed
# 2005.12.01~2005.12.31 done, 00:00:20 elapsed
# 2006.01.01~2006.01.31 done, 00:00:08 elapsed
# 2006.02.01~2006.02.28 done, 00:00:14 elapsed
# 2006.03.01~2006.03.31 done, 00:00:08 elapsed
# 2006.04.01~2006.04.30 done, 00:00:10 elapsed
# 2006.05.01~2006.05.31 done, 00:00:02 elapsed
# 2006.06.01~2006.06.30 done, 00:00:08 elapsed
# 2006.07.01~2006.07.31 done, 00:00:00 elapsed
# 2006.08.01~2006.08.31 done, 00:00:00 elapsed
# 2006.09.01~2006.09.30 done, 00:00:05 elapsed
# 2006.10.01~2006.10.31 done, 00:00:04 elapsed
# 2006.11.01~2006.11.30 done, 00:00:06 elapsed
# 2006.12.01~2006.12.31 done, 00:00:20 elapsed
# 2007.01.01~2007.01.31 done, 00:00:19 elapsed
# 2007.02.01~2007.02.28 done, 00:00:03 elapsed
# 2007.03.01~2007.03.31 done, 00:00:19 elapsed
# 2007.04.01~2007.04.30 done, 00:00:20 elapsed
# 2007.05.01~2007.05.31 done, 00:00:19 elapsed
# 2007.06.01~2007.06.30 done, 00:00:07 elapsed
# 2007.07.01~2007.07.31 done, 00:00:11 elapsed
# 2007.08.01~2007.08.31 done, 00:00:19 elapsed
# 2007.09.01~2007.09.30 done, 00:00:11 elapsed
# 2007.10.01~2007.10.31 done, 00:00:00 elapsed
# 2007.11.01~2007.11.30 done, 00:00:04 elapsed
# 2007.12.01~2007.12.31 done, 00:00:10 elapsed
# 2008.01.01~2008.01.31 done, 00:00:17 elapsed
# 2008.02.01~2008.02.29 done, 00:00:13 elapsed
# 2008.03.01~2008.03.31 done, 00:00:20 elapsed
# 2008.04.01~2008.04.30 done, 00:00:03 elapsed
# 2008.05.01~2008.05.31 done, 00:00:04 elapsed
# 2008.06.01~2008.06.30 done, 00:00:10 elapsed
# 2008.07.01~2008.07.31 done, 00:00:18 elapsed
# 2008.08.01~2008.08.31 done, 00:00:16 elapsed
# 2008.09.01~2008.09.30 done, 00:00:20 elapsed
# 2008.10.01~2008.10.31 done, 00:00:22 elapsed
# 2008.11.01~2008.11.30 done, 00:00:17 elapsed
# 2008.12.01~2008.12.31 done, 00:00:16 elapsed
# 2009.01.01~2009.01.31 done, 00:00:17 elapsed
# 2009.02.01~2009.02.28 done, 00:00:20 elapsed
# 2009.03.01~2009.03.31 done, 00:00:20 elapsed
# 2009.04.01~2009.04.30 done, 00:00:30 elapsed
# 2009.05.01~2009.05.31 done, 00:00:23 elapsed
# 2009.06.01~2009.06.30 done, 00:00:20 elapsed
# 2009.07.01~2009.07.31 done, 00:00:21 elapsed
# 2009.08.01~2009.08.31 done, 00:00:19 elapsed
# 2009.09.01~2009.09.30 done, 00:00:25 elapsed
# 2009.10.01~2009.10.31 done, 00:00:19 elapsed
# 2009.11.01~2009.11.30 done, 00:00:19 elapsed
# 2009.12.01~2009.12.31 done, 00:00:23 elapsed
# 2010.01.01~2010.01.31 done, 00:00:14 elapsed
# 2010.02.01~2010.02.28 done, 00:00:16 elapsed
# 2010.03.01~2010.03.31 done, 00:00:18 elapsed
# 2010.04.01~2010.04.30 done, 00:00:30 elapsed
# 2010.05.01~2010.05.31 done, 00:00:20 elapsed
# 2010.06.01~2010.06.30 done, 00:00:26 elapsed
# 2010.07.01~2010.07.31 done, 00:00:35 elapsed
# 2010.08.01~2010.08.31 done, 00:00:22 elapsed
# 2010.09.01~2010.09.30 done, 00:00:22 elapsed
# 2010.10.01~2010.10.31 done, 00:00:18 elapsed
# 2010.11.01~2010.11.30 done, 00:00:19 elapsed
# 2010.12.01~2010.12.31 done, 00:00:17 elapsed
# 2011.01.01~2011.01.31 done, 00:00:22 elapsed
# 2011.02.01~2011.02.28 done, 00:00:17 elapsed
# 2011.03.01~2011.03.31 done, 00:00:27 elapsed
# 2011.04.01~2011.04.30 done, 00:00:28 elapsed
# 2011.05.01~2011.05.31 done, 00:00:24 elapsed
# 2011.06.01~2011.06.30 done, 00:00:20 elapsed
# 2011.07.01~2011.07.31 done, 00:00:25 elapsed
# 2011.08.01~2011.08.31 done, 00:00:32 elapsed
# 2011.09.01~2011.09.30 done, 00:00:16 elapsed
# 2011.10.01~2011.10.31 done, 00:00:19 elapsed
# 2011.11.01~2011.11.30 done, 00:00:27 elapsed
# 2011.12.01~2011.12.31 done, 00:00:20 elapsed
# 2012.01.01~2012.01.31 done, 00:00:16 elapsed
# 2012.02.01~2012.02.29 done, 00:00:19 elapsed
# 2012.03.01~2012.03.31 done, 00:00:21 elapsed
# 2012.04.01~2012.04.30 done, 00:00:19 elapsed
# 2012.05.01~2012.05.31 done, 00:00:22 elapsed
# 2012.06.01~2012.06.30 done, 00:00:17 elapsed
# 2012.07.01~2012.07.31 done, 00:00:23 elapsed
# 2012.08.01~2012.08.31 done, 00:00:17 elapsed
# 2012.09.01~2012.09.30 done, 00:00:23 elapsed
# 2012.10.01~2012.10.31 done, 00:00:21 elapsed
# 2012.11.01~2012.11.30 done, 00:00:18 elapsed
# 2012.12.01~2012.12.31 done, 00:00:21 elapsed
# 2013.01.01~2013.01.31 done, 00:00:18 elapsed
# 2013.02.01~2013.02.28 done, 00:00:20 elapsed
# 2013.03.01~2013.03.31 done, 00:00:22 elapsed
# 2013.04.01~2013.04.30 done, 00:00:27 elapsed
# 2013.05.01~2013.05.31 done, 00:00:20 elapsed
# 2013.06.01~2013.06.30 done, 00:00:20 elapsed
# 2013.07.01~2013.07.31 done, 00:00:18 elapsed
# 2013.08.01~2013.08.31 done, 00:00:19 elapsed
# 2013.09.01~2013.09.30 done, 00:00:19 elapsed
# 2013.10.01~2013.10.31 done, 00:00:26 elapsed
# 2013.11.01~2013.11.30 done, 00:00:18 elapsed
# 2013.12.01~2013.12.31 done, 00:00:19 elapsed
# 2014.01.01~2014.01.31 done, 00:00:20 elapsed
# 2014.02.01~2014.02.28 done, 00:00:20 elapsed
# 2014.03.01~2014.03.31 done, 00:00:19 elapsed
# 2014.04.01~2014.04.30 done, 00:00:20 elapsed
# 2014.05.01~2014.05.31 done, 00:00:23 elapsed
# 2014.06.01~2014.06.30 done, 00:00:22 elapsed
# 2014.07.01~2014.07.31 done, 00:00:20 elapsed
# 2014.08.01~2014.08.31 done, 00:00:20 elapsed
# 2014.09.01~2014.09.30 done, 00:00:26 elapsed
# 2014.10.01~2014.10.31 done, 00:00:19 elapsed
# 2014.11.01~2014.11.30 done, 00:00:18 elapsed
# 2014.12.01~2014.12.31 done, 00:00:20 elapsed
# 2015.01.01~2015.01.31 done, 00:00:17 elapsed
# 2015.02.01~2015.02.28 done, 00:00:24 elapsed
# 2015.03.01~2015.03.31 done, 00:00:21 elapsed
# 2015.04.01~2015.04.30 done, 00:00:21 elapsed
# 2015.05.01~2015.05.31 done, 00:00:21 elapsed
# 2015.06.01~2015.06.30 done, 00:00:21 elapsed
# 2015.07.01~2015.07.31 done, 00:00:20 elapsed
# 2015.08.01~2015.08.31 done, 00:00:21 elapsed
# 2015.09.01~2015.09.30 done, 00:00:19 elapsed
# 2015.10.01~2015.10.31 done, 00:00:20 elapsed
# 2015.11.01~2015.11.30 done, 00:00:22 elapsed
# 2015.12.01~2015.12.31 done, 00:00:19 elapsed
# 2016.01.01~2016.01.31 done, 00:00:18 elapsed
# 2016.02.01~2016.02.29 done, 00:00:18 elapsed
# 2016.03.01~2016.03.31 done, 00:00:17 elapsed
# 2016.04.01~2016.04.30 done, 00:00:20 elapsed
# 2016.05.01~2016.05.31 done, 00:00:22 elapsed
# 2016.06.01~2016.06.30 done, 00:00:21 elapsed
# 2016.07.01~2016.07.31 done, 00:00:20 elapsed
# 2016.08.01~2016.08.31 done, 00:00:20 elapsed
# 2016.09.01~2016.09.30 done, 00:00:21 elapsed
# 2016.10.01~2016.10.31 done, 00:00:20 elapsed
# 2016.11.01~2016.11.30 done, 00:00:21 elapsed
# 2016.12.01~2016.12.31 done, 00:00:22 elapsed
# 2017.01.01~2017.01.31 done, 00:00:22 elapsed
# 2017.02.01~2017.02.28 done, 00:00:26 elapsed
# 2017.03.01~2017.03.31 done, 00:00:19 elapsed
# 2017.04.01~2017.04.30 done, 00:00:22 elapsed
# 2017.05.01~2017.05.31 done, 00:00:23 elapsed
# 2017.06.01~2017.06.30 done, 00:00:23 elapsed
# 2017.07.01~2017.07.31 done, 00:00:22 elapsed
# 2017.08.01~2017.08.31 done, 00:00:22 elapsed
# 2017.09.01~2017.09.30 done, 00:00:17 elapsed
# 2017.10.01~2017.10.31 done, 00:00:18 elapsed
# 2017.11.01~2017.11.30 done, 00:00:24 elapsed
# 2017.12.01~2017.12.31 done, 00:00:22 elapsed
# 2018.01.01~2018.01.31 done, 00:00:24 elapsed
# 2018.02.01~2018.02.28 done, 00:00:22 elapsed
# 2018.03.01~2018.03.31 done, 00:00:21 elapsed
# 2018.04.01~2018.04.30 done, 00:00:21 elapsed
# 2018.05.01~2018.05.31 done, 00:00:22 elapsed
# 2018.06.01~2018.06.30 done, 00:00:24 elapsed
# 2018.07.01~2018.07.31 done, 00:00:19 elapsed
# 2018.08.01~2018.08.31 done, 00:00:27 elapsed
# 2018.09.01~2018.09.30 done, 00:00:20 elapsed
# 2018.10.01~2018.10.31 done, 00:00:24 elapsed
# 2018.11.01~2018.11.30 done, 00:00:23 elapsed
# 2018.12.01~2018.12.31 done, 00:00:23 elapsed
# 2019.01.01~2019.01.31 done, 00:00:21 elapsed
# 2019.02.01~2019.02.28 done, 00:00:24 elapsed
# 2019.03.01~2019.03.31 done, 00:00:16 elapsed
# Wall time: 1h 4min 22s

# %%
newsdf.ym.astype(int).agg([min,max])
# Out:
# min    200201
# max    201903
# Name: ym, dtype: int64

# %%
newsdf.head()
# Out:
#        ym      qry  date                             title  \
# 0  200201  가계부채+연체  None        [금융] "가계부채 급격한 증가세..위험 징후"
# 1  200201  가계부채+연체  None     "가계부채 과도한 증가는 `금융불안' 초래"<금융연>
# 2  200201  가계부채+연체  None            “가계부채 300조 초과…금융불안 요인”
# 3  200201  가계부채+연체  None     가계부채 올해 400조 돌파 예상 .. 한국금융연구원
# 4  200201  가계부채+연체  None  [은행 가계대출 왜 줄이나] 개인파산 급증땐 경기회복 찬물
#
#                                                 text
# 0  머니투데이\n\n[머니투데이] 한국금융연구원은 31일 가계부채의 급격한 증가나 규모...
# 1  `신용카드 부실이 도화선'(서울=연합뉴스) 한승호기자 = 가계부채의 과도한 증가는 ...
# 2  가계부채의 과도한 증가는 금융시장의 불안요인으로 작용할 수 있다는 주장이 나왔다.최...
# 3  최근 급증하고 있는 가계부채 규모는 아직 우려할 만한 수준은 아니라고 한국금융연구원...
# 4  소비거품인가 아니면 경기가 바닥을 치면서 나타나는 일시적 현상인가.\n\n\n\n최...

# %%
newsdf = pd.read_pickle('data/newsdf_가계부채_연체_03_19.pkl')

# %% [markdown]
# **월별로 기사합치기: newsdf -> ndf**

# %%
ndf = newsdf.groupby(['ym','qry'])['text'].apply(lambda x: x.sum()).to_frame().reset_index()

# %%
ndf.head()
# Out:
#        ym      qry                                               text
# 0  200201  가계부채+연체  머니투데이\n\n[머니투데이] 한국금융연구원은 31일 가계부채의 급격한 증가나 규모...
# 1  200202  가계부채+연체  PICK 안내 해당 언론사가 주요기사로\n\n직접 선정한 기사입니다. 언론사 편집판...
# 2  200203  가계부채+연체  이번 호황기에 가계대출규모가 적정수준을 넘어설 경우 다음 침체기엔 가계부실화가 더욱...
# 3  200204  가계부채+연체  지난 3월중 은행의 가계대출은 7조6천9백50억원이 늘어나 최근의 급등세를 이어갔다...
# 4  200205  가계부채+연체  카드 빚을 못갚아 발생하는 신용불량자가 해마다 급증하고 있다.금융감독원에 따르면 L...

# %% [markdown]
# **Tokenize : 명사,형용사,부사만**

# %%
pos_list = ['Adjective','Adverb','Noun']
tok_p = lambda doc: ['/'.join(t) for t in okt.pos(doc) if t[1] in pos_list] # okt.pos(doc): (사스, Noun) => 사스/Noun

# %%
# %%time
ndf['tok_txt'] = ndf.text.apply(tok_p) # tok_txt : tokenize된 text
# Out:
# Wall time: 7min 17s

# %% [markdown]
# **Doc2Vec**

# %%
import multiprocessing
cores = multiprocessing.cpu_count()
from tqdm import tqdm
tqdm.pandas(desc="progress-bar")
from sklearn import utils
cores
# Out:
# 4

# %%
tagdoc = lambda txt, ym: [TaggedDocument(words=txt,tags=[ym])]

# %%
tag_txt = ndf.apply(lambda x: tagdoc(x.tok_txt,x.ym),axis=1) # tag_txt : doc2vec 입력용으로 변환, 기사별

# %%
tag_txt = [t for x in tag_txt for t in x] # tag_txt : 모델개발용으로 하나로 합침

# %%
# %%time
# 토큰업로드
max_epochs = 30
vec_size = 10
alpha = 0.025

model_dbow_txt = Doc2Vec(dm=0,
                     vector_size=vec_size,
                     alpha=alpha, 
                     min_alpha=0.00025,
                     min_count=1,
                     workers=cores)
model_dbow_txt.build_vocab(tag_txt)
# 모델피팅
for epoch in range(30):
    model_dbow_txt.train(utils.shuffle([x for x in tqdm(tag_txt)]),
                    total_examples=model_dbow_txt.corpus_count,
                    epochs=10)
    model_dbow_txt.alpha -= 0.002
    model_dbow_txt.min_alpha = model_dbow_txt.alpha
# Wall time: 1min 36s
# Out:
# 100%|████████████████████████████████████| 203/203 [00:00<00:00, 203014.71it/s]
# 100%|████████████████████████████████████| 203/203 [00:00<00:00, 203014.71it/s]
# 100%|████████████████████████████████████| 203/203 [00:00<00:00, 203014.71it/s]
# 100%|████████████████████████████████████| 203/203 [00:00<00:00, 203014.71it/s]
# 100%|████████████████████████████████████████████████| 203/203 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████| 203/203 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████| 203/203 [00:00<?, ?it/s]
# 100%|████████████████████████████████████| 203/203 [00:00<00:00, 203014.71it/s]
# 100%|████████████████████████████████████| 203/203 [00:00<00:00, 203014.71it/s]
# 100%|████████████████████████████████████| 203/203 [00:00<00:00, 203014.71it/s]
# 100%|████████████████████████████████████████████████| 203/203 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████| 203/203 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████| 203/203 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████| 203/203 [00:00<?, ?it/s]
# 100%|████████████████████████████████████| 203/203 [00:00<00:00, 203014.71it/s]
# 100%|████████████████████████████████████| 203/203 [00:00<00:00, 202917.95it/s]
# 100%|████████████████████████████████████████████████| 203/203 [00:00<?, ?it/s]
# 100%|████████████████████████████████████| 203/203 [00:00<00:00, 202966.32it/s]
# 100%|████████████████████████████████████████████████| 203/203 [00:00<?, ?it/s]
# 100%|████████████████████████████████████| 203/203 [00:00<00:00, 203014.71it/s]
# 100%|████████████████████████████████████████████████| 203/203 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████| 203/203 [00:00<?, ?it/s]
# 100%|████████████████████████████████████| 203/203 [00:00<00:00, 203014.71it/s]
# 100%|████████████████████████████████████████████████| 203/203 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████| 203/203 [00:00<?, ?it/s]
# 100%|████████████████████████████████████| 203/203 [00:00<00:00, 203014.71it/s]
# 100%|████████████████████████████████████████████████| 203/203 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████| 203/203 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████| 203/203 [00:00<?, ?it/s]
# 100%|████████████████████████████████████| 203/203 [00:00<00:00, 202966.32it/s]
# Wall time: 1min 36s

# %%
# %%time
# 벡터라이징
dvec1 = list(map(lambda x: model_dbow_txt.infer_vector(x), ndf.tok_txt))
cname = ['dx'+str(i) for i in np.arange(1,vec_size+1)]
dvec1 = pd.DataFrame(dvec1,columns = cname)
# Wall time: 7.64 s
# Out:
# Wall time: 7.64 s

# %%
dvec1.head()
# Out:
#         dx1       dx2       dx3       dx4       dx5       dx6       dx7  \
# 0 -1.776291  1.542021  1.597268  0.751209 -1.631949  1.870075  2.680017
# 1 -1.875534  1.670924  1.321456  0.831445 -1.589836  1.795084  2.737084
# 2 -1.845810  1.604996  1.596623  0.861379 -1.735235  1.710102  2.655217
# 3 -1.819431  1.612369  1.523840  1.058730 -1.659171  1.707307  2.584226
# 4 -1.952735  1.450928  1.688740  0.928315 -1.603917  1.766953  2.551003
#
#         dx8       dx9      dx10
# 0  1.847535  0.437508  0.950329
# 1  1.845110  0.428238  0.961790
# 2  2.043782  0.195656  0.877945
# 3  2.097419  0.331337  1.072828
# 4  1.957331  0.449868  0.908663

# %%
bidx = pd.read_pickle('data/busil_idx.pkl')
bidx.ym = bidx.ym.astype(str)

# %%
ndf2 = pd.concat([ndf,dvec1],axis=1)

# %%
ndf2 = ndf2.merge(bidx,how='left',left_on='ym',right_on='ym')

# %%
ndf2['date'] = pd.to_datetime(ndf2.ym, format='%Y%m')

# %%
ndf2.head()
# Out:
#        ym      qry                                               text  \
# 0  200201  가계부채+연체  머니투데이\n\n[머니투데이] 한국금융연구원은 31일 가계부채의 급격한 증가나 규모...
# 1  200202  가계부채+연체  PICK 안내 해당 언론사가 주요기사로\n\n직접 선정한 기사입니다. 언론사 편집판...
# 2  200203  가계부채+연체  이번 호황기에 가계대출규모가 적정수준을 넘어설 경우 다음 침체기엔 가계부실화가 더욱...
# 3  200204  가계부채+연체  지난 3월중 은행의 가계대출은 7조6천9백50억원이 늘어나 최근의 급등세를 이어갔다...
# 4  200205  가계부채+연체  카드 빚을 못갚아 발생하는 신용불량자가 해마다 급증하고 있다.금융감독원에 따르면 L...
#
#                                              tok_txt       dx1       dx2  \
# 0  [머니투데이/Noun, 머니투데이/Noun, 한국/Noun, 금융/Noun, 연구원... -1.776291  1.542021
# 1  [안내/Noun, 해당/Noun, 언론사/Noun, 기사/Noun, 직접/Noun,... -1.875534  1.670924
# 2  [이번/Noun, 호황/Noun, 기/Noun, 가계/Noun, 대출/Noun, 규... -1.845810  1.604996
# 3  [지난/Noun, 은행/Noun, 가계/Noun, 대출/Noun, 백/Noun, 최... -1.819431  1.612369
# 4  [카드/Noun, 빚/Noun, 발생/Noun, 신용/Noun, 불량/Noun, 해... -1.952735  1.450928
#
#         dx3       dx4       dx5       dx6       dx7       dx8       dx9  \
# 0  1.597268  0.751209 -1.631949  1.870075  2.680017  1.847535  0.437508
# 1  1.321456  0.831445 -1.589836  1.795084  2.737084  1.845110  0.428238
# 2  1.596623  0.861379 -1.735235  1.710102  2.655217  2.043782  0.195656
# 3  1.523840  1.058730 -1.659171  1.707307  2.584226  2.097419  0.331337
# 4  1.688740  0.928315 -1.603917  1.766953  2.551003  1.957331  0.449868
#
#        dx10  cycle  tcycle  가계소득지표  가계소비지표  차입수준지표       date
# 0  0.950329    NaN     NaN     NaN     NaN     NaN 2002-01-01
# 1  0.961790    NaN     NaN     NaN     NaN     NaN 2002-02-01
# 2  0.877945    NaN     NaN     NaN     NaN     NaN 2002-03-01
# 3  1.072828    NaN     NaN     NaN     NaN     NaN 2002-04-01
# 4  0.908663    NaN     NaN     NaN     NaN     NaN 2002-05-01

# %%
ndf2.to_pickle('data/ndf2.pkl')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.plot_date('date','dx1','-',color='steelblue',data=ndf2)

# %%
import matplotlib.dates as mdates
years = mdates.YearLocator(base=3)
yrfmt = mdates.DateFormatter("'%y'")

# %%
fig, ax = plt.subplots(2,5,figsize=(13,4))
n = 1
for i in range(2):
    for j in range(5):
        y = 'dx'+str(n)
        ax[i,j].plot_date('date',y,'-',data=ndf2)
        ax[i,j].set_title(y)
        ax[i,j].xaxis.set_major_locator(years)
        ax[i,j].xaxis.set_major_formatter(yrfmt)
        n += 1
plt.tight_layout()

# %%
import gc;gc.collect()
# Out:
# 37968

# %% [markdown]
# ### **PCA**

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=10)

# %%
pca1 = pca.fit(dvec1)

# %%
pca1.explained_variance_ratio_
# Out:
# array([0.16601812, 0.153602  , 0.12625247, 0.11193957, 0.10592423,
#        0.09378838, 0.08763555, 0.07198153, 0.06639138, 0.01646678])

# %%
pca1.mean_
# Out:
# array([-1.83093189,  1.63190981,  1.53635553,  0.86591118, -1.60622456,
#         1.71379837,  2.71125362,  1.93517887,  0.32675566,  0.94449348])

# %%
pcs = pca1.fit_transform(dvec1)

# %%
pcs = pd.DataFrame(pcs,columns = ['pc'+str(i+1) for i in range(10)])

# %%
pcs.head()
# Out:
#         pc1       pc2       pc3       pc4       pc5       pc6       pc7  \
# 0 -0.188696 -0.022022  0.004274  0.027130 -0.111743 -0.099001 -0.098589
# 1 -0.002505  0.177529 -0.102165  0.129276 -0.048528 -0.053892 -0.072567
# 2  0.068305 -0.080767  0.017485 -0.187706 -0.026470  0.077103 -0.026847
# 3  0.071024 -0.074221 -0.127780 -0.102695  0.209445 -0.011361 -0.103424
# 4  0.007739 -0.123667  0.111918 -0.050770  0.072582 -0.225418 -0.138297
#
#         pc8       pc9      pc10
# 0  0.001779 -0.070836  0.010007
# 1 -0.084523  0.022578 -0.016821
# 2 -0.016484 -0.058190 -0.007344
# 3  0.081512  0.029655 -0.000348
# 4  0.030123 -0.116468 -0.003368

# %%
ndf3 = pd.concat([ndf2,pcs], axis=1)

# %%
ndf3.to_pickle('data/ndf3.pkl')
ndf3.to_pickle('o:/보낼파일함/ndf3.pkl')

# %%
gc.collect()
# Out:
# 156608

# %%
sns.pairplot(pcs)

# %%
sns.pairplot(dvec1)
